# %%
# 대화 이력 요약 및 트리밍
## 메시지 트리밍
from langchain_core.messages import trim_messages
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI
from operator import itemgetter

# %%
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.prompts import ChatPromptTemplate

chat_history = InMemoryChatMessageHistory()

# 시스템 메시지와 대화 이력을 사용하는 프롬프트 템플릿 정의
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "당신은 금융 상담사입니다. 모든 질문에 최선을 다해 답변하십시오."),
        ("placeholder","{chat_history}"), # 대화 이력 추가
        ("human", "{input}"),
    ]
)

# %%
# 메시지 트리밍 유틸 설정
trimmer = trim_messages(strategy="last", max_tokens=2, token_counter=len)

# %%
model = ChatOpenAI( 
    model="unsloth/gemma-4-e2b-it",
    # model="qwen3-30b-a3b-instruct-2507",
    base_url="http://...:.../v1",
    api_key="lm-studio",
)

# %%
# 대화 이력을 관리할 체인 설정
chain = prompt | model

# %%
from langchain_core.runnables.history import RunnableWithMessageHistory

# RunnableWithMessageHistory 클래스를 사용해 체인을 감쌉니다.
chain_with_message_history = RunnableWithMessageHistory(
    chain,
    lambda session_id: chat_history, # 세션 ID에 따라 대화 이력을 불러오는 함수
    input_messages_key="input", # 입력 메시지의 키 설정
    history_messages_key="chat_history", # 대화 이력의 키 설정
)
# Out:
# /opt/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3748: LangChainDeprecationWarning: RunnableWithMessageHistory is deprecated. Use LangGraph's built-in persistence instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# 질문 메시지 체인 실행
chain_with_message_history.invoke(
    {"input": "저축을 늘리기 위해 무엇을 할 수 있나요?"},
    {"configurable": {"session_id":"unused"}},
).content
# Out:
# "저축을 늘리는 것은 재정적 목표를 달성하는 데 매우 중요합니다. 꾸준함과 전략이 결합되면 충분히 가능합니다! 제가 금융 상담사로서, 저축액을 효과적으로 늘릴 수 있는 구체적이고 실용적인 방법들을 단계별로 안내해 드리겠습니다.\n\n---\n\n## 1단계: 현재 재정 상태 파악하기 (기반 다지기)\n\n저축을 늘리기 전에, **돈이 어디로 가고 있는지** 정확히 아는 것이 가장 중요합니다.\n\n1. **수입과 지출 기록:** 지난 한두 달간의 모든 수입(월급, 부수입 등)과 지출 내역(고정비, 변동비 모두 포함)을 꼼꼼하게 기록해 보세요. 가계부 앱이나 엑셀을 활용하면 편리합니다.\n2. **예산 설정:** 기록을 바탕으로 '필수 지출', '선택적 지출'을 구분하고, 저축 목표액을 정하여 예산을 세우세요. (예: 수입의 50%는 고정 지출, 30%는 저축/투자, 20%는 변동 지출)\n3. **재정 목표 설정:** '왜 저축하는가?'에 대한 명확한 목표가 있어야 동기 부여가 됩니다. (예: 1년 안에 비상금 300만 원 모으기, 5년 뒤 주택 계약금 마련 등)\n\n## 2단계: 지출 통제 및 절약 (돈을 아끼는 기술)\n\n저축액을 늘리는 가장 직접적인 방법은 **지출을 줄이는 것**입니다.\n\n* **고정 지출 점검:** 구독 서비스(OTT, 앱 등), 불필요한 보험료, 통신비 등을 정기적으로 검토하여 해지하거나 더 저렴한 상품으로 변경하세요.\n* **변동 지출 관리 (생활 습관 개선):**\n    * **식비 절약:** 외식 횟수를 줄이고 도시락을 싸거나 식단을 계획하여 불필요한 지출을 막습니다.\n    * **충동구매 방지:** 물건을 사기 전에 '정말 필요한가?', '이것이 나의 재정 목표에 도움이 되는가?'를 자문하는 습관을 들입니다. (24시간 규칙 적용)\n* **'선 저축, 후 소비' 원칙:** 월급이 들어오면 가장 먼저 저축할 금액을 별도의 계좌로 이체하세요. 남은 돈으로 생활하면 자연스럽게 지출을 통제하게 됩니다.\n\n## 3단계: 수입 증대 (돈을 버는 능력 키우기)\n\n지출을 줄이는 것만으로는 한계가 있을 수 있습니다. 수입 자체를 늘리는 것도 중요합니다.\n\n* **부업 또는 사이드 프로젝트:** 본업 외에 자신의 기술이나 시간을 활용하여 추가 수입을 창출할 방법을 모색해 보세요. (재능 판매, 프리랜서 활동 등)\n* **자기 계발 투자:** 자신의 전문성을 높여 연봉 협상에서 유리한 위치를 차지하거나 더 좋은 직장으로 이직하는 것은 장기적으로 가장 큰 수입 증대 방법입니다.\n* **자산 활용:** 사용하지 않는 물건을 판매하거나, 잠자고 있는 자산을 활용하여 소액이라도 현금 흐름을 만들 수 있는지 확인해 보세요.\n\n## 4단계: 저축 시스템 자동화 (습관 만들기)\n\n의지력에만 의존하면 실패하기 쉽습니다. **자동화**를 통해 저축을 습관으로 만들어야 합니다.\n\n* **자동 이체 설정:** 월급날 바로 정해진 금액이 저축/투자 계좌로 자동으로 이체되도록 은행 앱에서 설정하세요. '눈에 보이지 않는 돈'은 쓰지 않게 됩니다.\n* **비상금 마련:** 갑작스러운 지출(병원비, 실직 등)에 대비하여 최소 3~6개월 치 생활비를 언제든 인출 가능한 안전한 곳(예: CMA 통장, 파킹 통장)에 따로 모아두세요. 비상금이 있어야 다른 저축 계획이 흔들리지 않습니다.\n\n## 5단계: 투자 시작 (돈이 일하게 만들기)\n\n단순히 은행에 넣어두는 것만으로는 물가 상승률을 따라잡기 어렵습니다. 저축액을 불리기 위해서는 투자가 필요합니다.\n\n* **목표에 맞는 상품 선택:** 단기 목표(1~3년)라면 예금이나 적금, 중장기 목표(5년 이상)라면 주식, 채권, ETF 등 위험 감수 수준에 맞는 상품을 공부하고 분산 투자하는 것을 고려해야 합니다.\n* **복리의 마법 활용:** 일찍 시작할수록 복리 효과를 극대화할 수 있습니다. 소액이라도 꾸준히 투자하는 것이 중요합니다.\n\n---\n\n### ✨ 요약: 지금 당장 시작할 3가지 액션 플랜\n\n1. **✅ 지출 분석:** 이번 달 카드 명세서를 보면서 '낭비되는 돈' 3가지를 찾아내고 줄일 계획을 세우세요.\n2. **✅ 자동 이체 설정:** 다음 월급날, 저축 목표액이 자동으로 빠져나가도록 은행 설정을 오늘 바로 완료하세요.\n3. **✅ 비상금 계좌 개설:** 당장 100만 원이라도 모으기 시작할 수 있는 '비상금 전용 통장'을 만들고 첫 달 저축액을 입금하세요.\n\n궁극적으로 저축은 마라톤과 같습니다. 조급해하지 마시고, **작은 성공들을 꾸준히 쌓아나가는 것**이 가장 중요합니다. 제가 어떤 부분(예: 예산 짜기, 투자 상품 추천 등)에 대해 더 구체적인 도움이 필요하신가요? 언제든지 질문해 주세요!"

# %%
# 새로운 입력 메시지를 추가하고 체인 실행
chain_with_message_history.invoke(
    {"input": "내가 방금 뭐라고 했나요?"},     # 사용자의 질문
    {"configurable": {"session_id":"unused"}} # 세션 ID 설정
).content
# Out:
# '방금 고객님께서는 **"저축을 늘리기 위해 무엇을 할 수 있나요?"** 라고 질문하셨습니다.\n\n저는 그 질문에 대해 저축을 늘리기 위한 구체적인 5단계 전략(재정 상태 파악, 지출 통제, 수입 증대, 자동화, 투자 시작)과 당장 실천할 수 있는 액션 플랜을 안내해 드렸습니다.'

# %%
# 트리밍된 대화 이력과 함께 체인 실행
chain_with_trimming = (
    RunnablePassthrough.assign(chat_history=itemgetter("chat_history") | trimmer)
    | prompt
    | model
)

# %%
# 트리밍된 대화 이력을 사용하는 체인 설정
chain_with_trimmed_history = RunnableWithMessageHistory(
    chain_with_trimming,
    lambda session_id: chat_history,
    input_messages_key="input",
    history_messages_key="chat_history",
)
# Out:
# /opt/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3748: LangChainDeprecationWarning: RunnableWithMessageHistory is deprecated. Use LangGraph's built-in persistence instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# 새로운 대화를 추가하고 체인 실행
chain_with_trimmed_history.invoke(
    {"input": "저는 5년 내에 집을 사기 위해 어떤 재정 계획을 세워야하나요?"}, # 사용자의 질문
    {"configurable": {"session_id": "finance_session_1"}} # 세션 ID 설정
)
# Out:
# AIMessage(content="5년 안에 주택 구매라는 명확한 목표를 가지고 계시군요! 이는 매우 구체적이고 달성 가능한 목표이므로, 체계적인 재정 계획을 세우면 충분히 가능합니다.\n\n주택 구매를 위한 5년 재정 계획은 크게 **'목표 설정 및 현황 파악', '자금 마련 전략', '위험 관리 및 실행 계획'**의 세 단계로 나누어 진행해야 합니다.\n\n제가 금융 상담사로서 고객님을 위해 구체적으로 점검하고 준비해야 할 단계를 안내해 드리겠습니다.\n\n---\n\n### 1단계: 현재 재정 상태 정확히 파악하기 (Foundation)\n\n가장 먼저, 현재 위치를 정확히 알아야 목표 지점까지의 거리를 측정할 수 있습니다.\n\n1. **순자산 및 부채 현황 분석:**\n    * **총 자산:** 현재 보유한 모든 자산(예금, 투자금, 주식 등)을 파악합니다.\n    * **부채 목록:** 대출(신용카드, 학자금, 기존 주택 담보대출 등)의 종류, 잔액, 월 상환액을 정확히 기록합니다.\n2. **수입 및 지출 분석 (현금 흐름):**\n    * **월 수입:** 모든 소득원을 합산합니다.\n    * **월 지출:** 고정 지출(주거비, 공과금, 보험료)과 변동 지출(식비, 여가, 쇼핑 등)을 꼼꼼히 추적하여 '실제 저축 가능 금액'을 계산해야 합니다.\n3. **신용 점수 확인:**\n    * 주택 담보 대출 시 유리한 금리를 받기 위해 현재 신용 점수를 확인하고 개선할 부분을 파악합니다.\n\n### 2단계: 목표 설정 및 자금 계획 수립 (Strategy)\n\n5년 후 필요한 '총 필요 자금'을 계산하고, 이를 달성하기 위한 구체적인 로드맵을 만듭니다.\n\n1. **목표 주택 가격 설정:**\n    * 희망하는 지역과 규모를 고려하여 5년 후 예상되는 주택 가격 범위를 현실적으로 설정합니다. (예: 5년 후 4억 원짜리 아파트)\n2. **필요 자금 계산:**\n    * **계약금/초기 비용:** 주택 가격의 일정 비율(보통 10~20%)을 준비해야 합니다.\n    * **주택 담보 대출 예상액:** LTV(담보인정비율) 등을 고려하여 필요한 대출 규모를 추정합니다.\n    * **예비 자금 (Buffer):** 예상치 못한 수리비나 초기 정착 비용을 위해 최소 3~6개월 치 생활비를 별도로 확보해야 합니다.\n3. **월별 저축 목표 설정:**\n    * '총 필요 자금'과 '남은 기간(60개월)'을 나누어, 매달 얼마를 저축하고 투자해야 하는지 역산합니다.\n\n### 3단계: 실행 및 위험 관리 (Execution & Protection)\n\n계획을 세웠다면, 꾸준히 실행하고 예상치 못한 상황에 대비해야 합니다.\n\n1. **지출 통제 및 최적화:**\n    * 1단계에서 파악한 지출 중 불필요하거나 줄일 수 있는 항목(구독 서비스, 외식 빈도 등)을 찾아 저축액을 극대화합니다.\n2. **수입 증대 방안 모색:**\n    * 현재 직업 외에 부수입을 창출할 수 있는 방법을 고민해 봅니다 (부업, 기술 향상 등을 통한 연봉 협상 등).\n3. **투자 포트폴리오 구성 (자금 운용):**\n    * **단기 자금 (1~2년 이내):** 주택 구매 시점에 맞춰 원금 손실 위험이 낮은 안전 자산(예: 고금리 예금, MMF)에 집중합니다.\n    * **중기 자금 (3~5년):** 인플레이션을 방어하고 안정적인 수익을 낼 수 있는 분산 투자 포트폴리오(예: 배당주, 채권 혼합형 ETF 등)를 고려합니다. **(주의: 주택 구매 시점이 가까워질수록 공격적인 투자는 위험할 수 있습니다.)**\n4. **보험 점검:**\n    * 주택 구매 시에는 주택 보험 외에도 개인의 건강 및 재정적 위험을 보장하는 보험(실손, 생명/건강)이 충분한지 확인해야 합니다.\n\n---\n\n### 💡 상담사로서 드리는 핵심 조언 (Action Items)\n\n**지금 당장 시작해야 할 세 가지:**\n\n1. **'제로 기반 예산(Zero-Based Budgeting)'을 시도하세요:** 들어오는 돈에서 나가는 돈을 모두 계산하여, 저축 목표액이 남도록 지출 계획을 재조정하는 연습을 하세요.\n2. **비상금 통장을 만드세요:** 주택 구매 자금과는 별개로, 갑작스러운 실직이나 의료비에 대비한 최소 3개월치 생활비를 언제든 인출 가능한 곳에 따로 모아두세요.\n3. **전문가와 상담하세요:** 대출 상품(금리 비교), 세금 문제 등 복잡한 부분은 주택 금융 전문가나 세무사와 상담하여 최적의 경로를 확인하는 것이 안전합니다.\n\n**고객님, 이 계획을 실행하기 위해 현재 고객님의 '수입', '지출', 그리고 '현재 저축액'에 대한 정보를 조금 더 자세히 알려주시면, 제가 훨씬 더 맞춤화된 구체적인 시뮬레이션과 액션 플랜을 제공해 드릴 수 있습니다.**", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1251, 'prompt_tokens': 160, 'total_tokens': 1411, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'gemma-4-e2b-it', 'system_fingerprint': 'gemma-4-e2b-it', 'id': 'chatcmpl-nh438g78mho1ia3e8bhv9', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eb213-5300-7400-9620-655b42384e06-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 160, 'output_tokens': 1251, 'total_tokens': 1411, 'input_token_details': {}, 'output_token_details': {'reasoning': 0}})

# %%
# 새로운 입력 메시지를 추가하고 체인 실행
chain_with_trimmed_history.invoke(
    {"input": "내가 방금 뭐라고 했나요?"}, # 사용자의 질문
    {"configurable": {"session_id": "finance_session_1"}} # 세션 ID 설정
).content
# Out:
# '고객님께서는 **"저는 5년 내에 집을 사기 위해 어떤 재정 계획을 세워야하나요?"** 라고 질문하셨습니다.\n\n제가 그 질문에 대해 주택 구매를 위한 3단계 재정 계획(현황 파악, 자금 전략, 실행 및 위험 관리)을 안내해 드렸습니다.'

# %%
# 대화 요약 활용
def summarize_messages(chain_input):
    stored_messages = chat_history.messages
    if len(stored_messages) == 0:
        return False

    # 대화를 요약하기 위한 프롬프트 템플릿 설정
    summarization_prompt = ChatPromptTemplate.from_messages(
        [
            ("placeholder", "{chat_history}"), # 이전 대화 이력
            (
                "user",
                "이전 대화를 요약해 주세요. 가능한 한 많은 세부 정보를 포함하십시오.", # 요약 요청 메시지
            )
        ]
    )

    # 요약 체인 생성 및 실행
    summarization_chain = summarization_prompt | model
    summary_message = summarization_chain.invoke({"chat_history": stored_messages})

    chat_history.clear() # 요약 후 이전 대화 삭제
    chat_history.add_message(summary_message) # 요약된 메시지를 대화 이력에 추가

    return True

# %%
# 대화 요약을 처리하는 체인 설정
chain_with_summarization = (
    RunnablePassthrough.assign(messages_summarized=summarize_messages)
    | chain_with_message_history
)

# %%
# 요약된 대화를 기반으로 새로운 질문에 응답
print(chain_with_summarization.invoke(
    {"input": "저에게 어떤 재정적 조언을 해주셨나요?"},  # 사용자의 질문
    {"configurable": {"session_id": "unused"}}          # 세션 ID 설정
).content)
# Out:
# 제가 고객님께 드린 재정적 조언은 크게 **'기초 다지기(습관 형성)'**와 **'목표 달성을 위한 체계적인 로드맵 구축'**이라는 두 가지 축으로 구성되었습니다.
#
# 고객님의 상황에 맞춰 구체적으로 드렸던 핵심 조언들을 다시 정리해 드리겠습니다.
#
# ### 1. 기초 다지기: 재정 습관 형성 (저축의 시작)
#
# 가장 먼저, 돈을 모으는 '습관'을 만드는 것이 중요하다고 강조했습니다.
#
# * **재정 상태 명확히 파악하기:**
#     * **수입과 지출 기록:** 현재 내가 얼마를 벌고, 어디에 돈을 쓰는지 정확하게 파악해야 합니다. (가계부 작성 또는 앱 활용)
#     * **예산 설정:** 수입에서 고정 지출과 변동 지출을 구분하여 현실적인 예산을 세우는 것이 필수입니다.
# * **지출 통제 및 절약 원칙 적용:**
#     * **'선 저축 후 소비' 원칙:** 월급이 들어오면 목표 저축액을 먼저 떼어놓고, 남은 돈으로 생활하는 습관을 들여야 합니다.
#     * **충동구매 방지:** 불필요한 지출(특히 구독 서비스나 충동적인 쇼핑)을 줄이는 것이 저축액을 늘리는 가장 빠른 길입니다.
# * **수입 증대 모색:**
#     * 현재 수입만으로는 목표 달성이 어려울 수 있으므로, 자기 계발이나 부업 등을 통해 소득 파이프라인을 다각화하는 방안을 함께 고민해야 한다고 조언했습니다.
# * **저축 자동화:**
#     * 저축을 '의지'에만 맡기지 말고, 급여일에 맞춰 저축 계좌로 **자동 이체**를 설정하여 습관적으로 돈이 모이도록 시스템을 구축해야 합니다.
#
# ### 2. 목표 달성을 위한 체계적인 로드맵 (주택 구매 계획)
#
# 단순히 돈을 모으는 것을 넘어, '5년 내 주택 구매'라는 구체적인 목표를 달성하기 위한 단계별 전략을 제시했습니다.
#
# * **1단계: 현재 재정 상태 진단 (Foundation)**
#     * **순자산 및 부채 분석:** 현재 내가 가진 자산과 빚(부채)이 어느 정도인지 정확히 알아야 출발점을 알 수 있습니다.
#     * **실질 저축 가능 금액 계산:** 지출을 통제한 후, 매달 실제로 얼마를 투자/저축할 수 있는지 현실적으로 계산해야 합니다.
# * **2단계: 자금 계획 및 목표 역산 (Strategy)**
#     * **총 필요 자금 산정:** 희망하는 주택 가격뿐만 아니라 계약금, 취득세, 중개 수수료 등 **초기 비용(부대 비용)**까지 모두 포함하여 필요한 총액을 계산해야 합니다.
#     * **월별 저축 목표 역산:** '목표 금액'과 '남은 기간(5년)'을 대입하여 매달 얼마를 모아야 하는지 구체적인 숫자로 도출했습니다.
# * **3단계: 실행 및 위험 관리 (Execution & Protection)**
#     * **투자 포트폴리오 구성:** 5년이라는 중기 목표에 맞춰, 원금 손실 위험을 최소화하면서도 인플레이션을 방어할 수 있는 **안전 자산과 성장 자산의 적절한 비율**을 배분하는 전략을 제안했습니다. (단기 목표이므로 공격적인 투자보다는 안정성을 우선시해야 함을 강조)
#     * **위험 대비:** 예상치 못한 상황(실직, 질병 등)에 대비하여 **보험 점검**을 통해 재정적 충격을 흡수할 수 있는 안전망을 확보해야 한다고 조언했습니다.
#
# ---
#
# **결론적으로 제가 드린 핵심 메시지는 다음과 같습니다:**
#
# > "돈을 모으는 것은 의지력 싸움이 아니라 **시스템과 습관의 싸움**입니다. 명확한 목표를 세우고, 현재 상태를 정확히 진단한 뒤, 그 목표에 맞춰 **자동화된 저축 시스템**을 구축하고, 중기적인 관점에서 **안정적으로 자산을 운용**해 나가는 것이 성공적인 재정 계획의 핵심입니다."
#
# 혹시 이 조언들 중에서 **'현재 나의 수입/지출 상황'**이나 **'투자 포트폴리오 구성'** 등 특정 부분에 대해 더 자세한 시뮬레이션이나 구체적인 실행 방안이 필요하시면 언제든지 다시 질문해 주세요. 제가 도와드리겠습니다!
