# %%
# !pip install openai langchain_core langchain_openai
# Out:
# Requirement already satisfied: openai in /opt/venv/lib/python3.12/site-packages (2.38.0)
# Collecting langchain_core
#   Downloading langchain_core-1.4.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-1.2.2-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/venv/lib/python3.12/site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/venv/lib/python3.12/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/venv/lib/python3.12/site-packages (from openai) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/venv/lib/python3.12/site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in /opt/venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/venv/lib/python3.12/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/venv/lib/python3.12/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /opt/venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.17)
# Requirement already satisfied: certifi in /opt/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /opt/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain_core)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.14 (from langchain_core)
#   Downloading langchain_protocol-0.0.16-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain_core)
#   Downloading langsmith-0.8.9-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in /opt/venv/lib/python3.12/site-packages (from langchain_core) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/venv/lib/python3.12/site-packages (from langchain_core) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain_core)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain_core)
#   Downloading uuid_utils-0.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /opt/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.9)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in /opt/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in /opt/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (16.0)
# Requirement already satisfied: xxhash>=3.0.0 in /opt/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.7.0)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Downloading zstandard-0.25.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /opt/venv/lib/python3.12/site-packages (from langchain_openai) (0.13.0)
# Requirement already satisfied: regex in /opt/venv/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2026.1.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.7.0)
# Downloading langchain_core-1.4.1-py3-none-any.whl (549 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 18.3 MB/s  0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.8.9-py3-none-any.whl (403 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Downloading langchain_openai-1.2.2-py3-none-any.whl (99 kB)
# Downloading langchain_protocol-0.0.16-py3-none-any.whl (7.0 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading zstandard-0.25.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 3.1 MB/s  0:00:01 eta 0:00:01m
# Installing collected packages: zstandard, uuid-utils, tenacity, langchain-protocol, jsonpatch, requests-toolbelt, langsmith, langchain_core, langchain_openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [langchain_openai][langchain_core]
# Successfully installed jsonpatch-1.33 langchain-protocol-0.0.16 langchain_core-1.4.1 langchain_openai-1.2.2 langsmith-0.8.9 requests-toolbelt-1.0.0 tenacity-9.1.4 uuid-utils-0.16.0 zstandard-0.25.0

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
# 프롬프트 템플릿 정의
prompt = ChatPromptTemplate.from_template("주제 {topic}에 대해 짧은 설명을 해주세요.")

# %%
model = ChatOpenAI( 
    model="unsloth/gemma-4-e2b-it",
    base_url="http://...:.../v1",
    api_key="lm-studio",
    temperature=0.7
)

# %%
output_parser = StrOutputParser() # 출력 파서를 문자열로 설정

# %%
# 파이프라인 설정 : 주제를 받아 프롬프트 생성 -> 모델 응답 -> 문자열 파싱
chain = (
    {"topic": RunnablePassthrough()}
    | prompt
    | model
    | output_parser
)

# %%
chain.invoke("더블딥")
# Out:
# '## 주제 더블딥(Topic Double Dip)에 대한 짧은 설명\n\n**주제 더블딥(Topic Double Dip)**은 **하나의 주제나 아이디어에 대해 너무 깊이, 혹은 반복적으로 집중하여 다루는 행위**를 비유적으로 이르는 말입니다.\n\n쉽게 말해, **"한 가지 주제에만 너무 몰두해서 다른 중요한 것들을 놓치거나, 같은 내용을 계속해서 반복하는 상황"**을 의미합니다.\n\n### 핵심 의미:\n\n* **과도한 집중:** 특정 주제에 에너지를 과도하게 쏟아붓습니다.\n* **깊이의 함정:** 겉핥기식 접근이 아니라, 한 지점에 너무 깊숙이 파고들어 다른 측면을 간과하게 만듭니다.\n* **반복성:** 같은 내용이나 관점을 끊임없이 재강조하여 지루해지거나 피로감을 유발합니다.\n\n### 사용되는 상황 예시:\n\n1. **글쓰기/발표:** 하나의 논점에 너무 많은 분량을 할애하여 다른 중요한 근거들을 생략할 때.\n2. **대화:** 한 사람의 특정 경험이나 의견에 대해 계속해서 같은 질문만 반복할 때.\n3. **학습:** 특정 개념 하나만 완벽하게 이해하려다 전체적인 맥락을 놓칠 때.\n\n**결론적으로, 주제 더블딥은 \'균형\'과 \'다각화\'의 중요성을 강조하며, 한 가지에 매몰되지 않고 여러 관점을 동시에 고려해야 함을 시사하는 경고의 의미를 담고 있습니다.**'
