# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

model = ChatOpenAI( 
    model="unsloth/gemma-4-e2b-it",
    base_url="http://...:.../v1",
    api_key="lm-studio",
)

# %%
prompt = ChatPromptTemplate.from_template("주제 {topic}에 대해 짧은 설명을 해주세요.")

# %%
parser = StrOutputParser()

# %%
chain = prompt | model | parser

# %%
# 주어진 주제 리스트에 대한 응답을 배치로 출력
chain.batch([{"topic": "더블딥"}, {"topic":"인플레이션"}])
# Out:
# ["## 주제 더블딥(Topic Double Dip)에 대한 짧은 설명\n\n**주제 더블딥(Topic Double Dip)**은 **하나의 주제나 아이디어를 두 번 이상, 혹은 매우 유사한 방식으로 반복하여 다루는 행위**를 의미합니다.\n\n쉽게 말해, **같은 이야기를 너무 자주, 혹은 너무 깊이 파고들어 지루하게 만드는 것**을 비판적으로 표현할 때 사용됩니다.\n\n### 핵심적인 의미:\n\n1. **반복성:** 동일하거나 매우 유사한 내용, 관점, 논점을 계속해서 제시합니다.\n2. **깊이의 부족 (또는 과잉):** 주제를 충분히 탐구하지 않고 같은 각도에서만 반복하거나, 반대로 너무 세부적인 부분에만 매몰되어 핵심을 놓치는 경우를 포함합니다.\n3. **지루함 유발:** 청중이나 독자가 이미 알고 있거나 지겨워하는 내용을 계속해서 들려주어 흥미를 잃게 만듭니다.\n\n### 사용되는 상황 예시:\n\n* **토론/강연:** 한 강연에서 A라는 문제에 대해 10분 동안 깊이 다룬 후, 다른 세션에서도 거의 동일한 방식으로 A에 대해 반복하는 경우.\n* **글쓰기:** 에세이나 기사에서 특정 논점을 여러 단락에 걸쳐 같은 방식으로 재진술하는 경우.\n\n**요약하자면, 주제 더블딥은 '같은 것을 너무 많이, 혹은 너무 똑같이 반복하여 피로감을 주는 것'을 지적하는 표현입니다.**",
#  '## 인플레이션(Inflation)에 대한 짧은 설명\n\n**인플레이션**이란 **물가 수준이 전반적으로 지속적으로 상승하는 현상**을 말합니다. 쉽게 말해, **돈의 가치가 떨어지고 물건을 사는 데 더 많은 돈이 필요하게 되는 상황**입니다.\n\n**핵심적인 의미:**\n\n* **구매력 하락:** 같은 금액의 돈으로 살 수 있는 물건의 양(구매력)이 줄어듭니다.\n* **물가 상승:** 식료품, 주거비, 서비스 등 전반적인 상품과 서비스의 가격이 오릅니다.\n\n**왜 발생할까요?**\n\n주로 다음과 같은 이유들로 인해 발생합니다.\n\n1. **수요 증가 (Demand-Pull Inflation):** 사람들이 돈을 더 많이 벌거나 소비를 늘려 물건에 대한 수요가 공급을 초과할 때 발생합니다. (너무 많은 돈이 시장에 풀릴 때)\n2. **비용 상승 (Cost-Push Inflation):** 원자재 가격, 임금 등 생산 비용이 증가하여 기업들이 그 비용을 제품 가격에 전가할 때 발생합니다.\n\n**결론적으로, 인플레이션은 경제 전반의 물가가 오르는 현상이며, 이는 화폐 가치 하락과 소비자의 실질 구매력 감소를 의미합니다.**']

# %%
# 응답을 토큰 단위로 스트리밍하여 출력
for token in chain.stream({"topic":"더블딥"}):
    # 스트리밍된 내용을 출력, 각 내용을 붙여서 출력하며 버퍼를 즉시 플러시하여 실시간으로 보여줌
    print(token, end="", flush=True)
# Out:
# ## 주제 더블딥(Topic Double Dip)에 대한 짧은 설명
#
# **주제 더블딥(Topic Double Dip)**은 **하나의 주제나 아이디어를 두 번 이상, 혹은 매우 유사한 방식으로 반복하여 다루는 행위**를 의미합니다.
#
# 쉽게 말해, **같은 이야기를 너무 자주, 혹은 너무 깊이 파고들어 지루하게 만드는 것**을 비판적으로 표현할 때 사용됩니다.
#
# ### 핵심 의미:
#
# 1. **반복성:** 동일하거나 매우 유사한 내용, 관점, 논점을 계속해서 제시합니다.
# 2. **깊이의 부족 (혹은 과잉):** 주제를 충분히 탐구하지 않고 같은 각도에서만 반복하거나, 반대로 너무 세부적인 부분만 반복하여 피상적으로 만드는 경우를 포함합니다.
# 3. **지루함 유발:** 청중이나 독자가 이미 알고 있거나 지겨워하는 내용을 계속해서 들려주어 흥미를 잃게 만듭니다.
#
# ### 사용되는 상황 예시:
#
# * **토론/강연:** 한 강연에서 A라는 문제에 대해 10분 동안 깊이 다룬 후, 다른 세션에서도 똑같은 A 문제를 다시 상세히 설명하는 경우.
# * **글쓰기:** 에세이나 보고서에서 핵심 주장을 여러 단락에 걸쳐 동일한 방식으로 반복하여 강조하는 경우.
# * **미디어:** 뉴스나 콘텐츠에서 특정 사건을 너무 많은 채널과 시간대에 걸쳐 같은 시각으로 계속 보도하는 경우.
#
# **요약하자면, 주제 더블딥은 '같은 것을 너무 많이, 혹은 너무 똑같이 반복해서 전달하는 것'에 대한 부정적인 평가입니다.**
