# %%
# 대화 이력 관리 및 처리
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# %%
model = ChatOpenAI( 
    model="unsloth/gemma-4-e2b-it",
    # model="qwen3-30b-a3b-instruct-2507",
    base_url="http://...:.../v1",
    api_key="lm-studio",
)

# %%
# 프롬프트 템플릿 정의: 금융 상담 역할
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "당신은 금융 상담사입니다. 사용자에게 최선의 금융 조언을 제공합니다."),
        ("placeholder","{messages}"), # 대화 이력 추가
    ]
)

# %%
# 프롬프트와 모델을 연결하여 체인 생성
chain = prompt | model

# %%
from langchain_community.chat_message_histories import ChatMessageHistory

# 대화 이력 저장을 위한 클래스 초기화
chat_history = ChatMessageHistory()

# 사용자 메시지 추가
chat_history.add_user_message("저축을 늘리기 위해 무엇을 할 수 있나요?")
chat_history.add_ai_message("저축 목표를 설정하고, 매달 자동 이체로 일정 금액을 저축하세요.")
# Out:
# /tmp/ipykernel_14026/3160851847.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.chat_message_histories import ChatMessageHistory

# %%
# DeprecationWarning 에 따른 수정
from langchain_core.chat_history import InMemoryChatMessageHistory

chat_history = InMemoryChatMessageHistory()
# 사용자 메시지 추가
chat_history.add_user_message("저축을 늘리기 위해 무엇을 할 수 있나요?")
chat_history.add_ai_message("저축 목표를 설정하고, 매달 자동 이체로 일정 금액을 저축하세요.")

# %%
# 새로운 질문 추가 후 다시 체인 실행
chat_history.add_user_message("방금 뭐라고 했나요?")
ai_response = chain.invoke({"messages": chat_history.messages})
print(ai_response.content) # 챗봇은 이전 메시지를 기억하여 답변합니다.
# Out:
# 제가 드린 조언은 **"저축 목표를 설정하고, 매달 자동 이체로 일정 금액을 저축하세요."** 입니다.
#
# 혹시 이 조언에 대해 더 자세한 설명이 필요하신가요? 예를 들어, 구체적으로 어떻게 목표를 세우거나 자동 이체를 설정하는지에 대해 알고 싶으신가요? 아니면 현재 재정 상황에 맞는 맞춤형 조언을 원하시나요? 😊

# %%
# 모델을 변경하여 테스트
model = ChatOpenAI( 
    # model="unsloth/gemma-4-e2b-it",
    model="qwen3-30b-a3b-instruct-2507",
    base_url="http://...:.../v1",
    api_key="lm-studio",
)

# %%
# 프롬프트 템플릿 정의: 금융 상담 역할
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "당신은 금융 상담사입니다. 사용자에게 최선의 금융 조언을 제공합니다."),
        ("placeholder","{messages}"), # 대화 이력 추가
    ]
)

# %%
# 프롬프트와 모델을 연결하여 체인 생성
chain = prompt | model

# %%
# DeprecationWarning 에 따른 수정
from langchain_core.chat_history import InMemoryChatMessageHistory

chat_history = InMemoryChatMessageHistory()
# 사용자 메시지 추가
chat_history.add_user_message("저축을 늘리기 위해 무엇을 할 수 있나요?")
chat_history.add_ai_message("저축 목표를 설정하고, 매달 자동 이체로 일정 금액을 저축하세요.")

# %%
# 새로운 질문 추가 후 다시 체인 실행
chat_history.add_user_message("방금 뭐라고 했나요?")
ai_response = chain.invoke({"messages": chat_history.messages})
print(ai_response.content) # 챗봇은 이전 메시지를 기억하여 답변합니다.
# Out:
# 저축을 늘리기 위해 가장 효과적인 방법은 **매달 자동으로 일정 금액을 저축 계좌로 이체하는 것**입니다.
#
# 이 방법은 다음과 같은 장점이 있어요:
#
# 1. **의지력에 의존하지 않음**
#    매월 자동으로 빠져나가는 돈이라서, "지금 쓰고 싶다"는 유혹을 피할 수 있습니다.
#
# 2. **습관 형성에 도움이 됨**
#    시간이 지나면 저축이 자연스러운 생활 습관이 되며, 점차 더 많은 금액도 저축하기 쉬워집니다.
#
# 3. **목표 달성을 쉽게 할 수 있음**
#    예: 월 10만 원을 자동 이체하면 연간 120만 원 저축 가능 → 목표 금액(예: 여행비, 비상금)에 빠르게 도달할 수 있어요.
#
# 💡 **추가 팁**:
# - 저축 계좌를 일반 통장이 아닌, **이자율이 높은 정기예금 또는 적금**으로 설정해 보세요.
# - 매월 예산을 세우고, ‘필수 지출’과 ‘선택적 소비’를 구분하여 불필요한 지출을 줄이는 것도 도움이 됩니다.
#
# > 예: 월급 300만 원 → 저축 50만 원(자동 이체), 생활비 200만 원, 나머지 50만 원은 자유 소비
#
# 필요하시면 **저축 계획표**나 **예산 짜는 방법**도 도와드릴 수 있어요.
