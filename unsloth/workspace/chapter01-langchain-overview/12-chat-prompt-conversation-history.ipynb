# %%
# 메모리 관리: 대화 기록 유지
## 기본적인 대화 이력 전달
# !pip install langchain-community langchain-core langchain langchain-openai langchain-chroma

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# %%
model = ChatOpenAI( 
    model="unsloth/gemma-4-e2b-it",
    # model="qwen3-30b-a3b-instruct-2507",
    base_url="http://...:.../v1",
    api_key="lm-studio",
)

# %%
# 프롬프트 템플릿 정의: 금융 상담 역할
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "당신은 금융 상담사입니다. 사용자에게 최선의 금융 조언을 제공합니다."),
        ("placeholder","{messages}"), # 대화 이력 추가
    ]
)

# %%
# 프롬프트와 모델을 연결하여 체인 생성
chain = prompt | model

# %%
# 이전 대화를 포함한 메시지 전달
ai_msg = chain.invoke(
    {
        "messages": [
            ("human", "저축을 늘리기 위해 무엇을 할 수 있나요?"), # 사용자의 첫 질문
            ("ai", "저축 목표를 설정하고, 매달 자동 이체로 일정 금액을 저축하세요."), # 챗봇의 답변 
            ("human", "방금 뭐라고 했나요?"), # 사용자의 재확인 질문
        ]
    }
)

print(ai_msg.content) # 챗봇의 응답 출력
# Out:
# 제가 드린 조언은 **"저축 목표를 설정하고, 매달 자동 이체로 일정 금액을 저축하세요."** 입니다.
#
# 혹시 이 조언에 대해 더 자세한 설명이 필요하신가요? 예를 들어, 구체적으로 어떻게 목표를 세우거나 자동 이체를 설정하는지에 대해 알고 싶으신가요? 아니면 현재 재정 상황에 맞는 맞춤형 조언을 원하시나요? 😊

# %%
model = ChatOpenAI( 
    # model="unsloth/gemma-4-e2b-it",
    model="qwen3-30b-a3b-instruct-2507",
    base_url="http://...:.../v1",
    api_key="lm-studio",
)

# %%
# 프롬프트 템플릿 정의: 금융 상담 역할
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "당신은 금융 상담사입니다. 사용자에게 최선의 금융 조언을 제공합니다."),
        ("placeholder","{messages}"), # 대화 이력 추가
    ]
)

# %%
# 프롬프트와 모델을 연결하여 체인 생성
chain = prompt | model

# %%
# 이전 대화를 포함한 메시지 전달
ai_msg = chain.invoke(
    {
        "messages": [
            ("human", "저축을 늘리기 위해 무엇을 할 수 있나요?"), # 사용자의 첫 질문
            ("ai", "저축 목표를 설정하고, 매달 자동 이체로 일정 금액을 저축하세요."), # 챗봇의 답변 
            ("human", "방금 뭐라고 했나요?"), # 사용자의 재확인 질문
        ]
    }
)

print(ai_msg.content) # 챗봇의 응답 출력
# Out:
# 저축을 늘리기 위해선 **매월 일정한 금액을 자동으로 저축하는 것**이 가장 효과적인 방법입니다. 예를 들어, 월급일에 10만 원을 통장에서 계좌 이체로 자동으로 저축하는 방식으로 하면, 의도적으로 쓰지 않아도 자연스럽게 저축이 되죠.
#
# 또한 아래와 같은 전략도 도움이 됩니다:
#
# 1. **저축 목표 설정하기**
#    예: “6개월 후 여행 자금 300만 원 모으기”처럼 구체적인 목표를 정하세요.
#
# 2. **목적별 계좌 분리하기**
#    일상 생활비는 일반 통장, 저축은 별도의 저축 계좌에 넣어 ‘눈에 보이지 않게’ 만드세요. (예: 비상금 전용 계좌, 투자 계좌 등)
#
# 3. **‘소비를 줄이는 것보다 저축을 먼저 하기’**
#    월급 받은 후 가장 먼저 저축하고, 남은 돈으로 생활비를 사용하는 ‘저축 우선 원칙’을 실천하세요.
#
# 4. **자동이체 설정하기**
#    은행 앱이나 온라인 뱅킹에서 자동 이체(예: 월급일 다음날 10만 원 저축)로 설정하면, 마음의 여유를 두고 저축할 수 있습니다.
#
# 💡 *팁*: “지금은 안 되겠지만, 나중에 해보자”는 생각보다는 “지금 시작해보자”는 작은 행동이 큰 변화를 만듭니다.
# 매달 5만 원이라도 자동으로 저축하면, 연간 60만 원, 10년 후에는 약 720만 원(복리 기준)이 됩니다!
#
# 필요하시면, 당신의 수입과 지출 상황에 맞는 **맞춤형 저축 계획**도 도와드릴 수 있어요.
