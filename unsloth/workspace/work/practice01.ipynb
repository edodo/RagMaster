# %%
#!pip install openai langchain_core langchain_openai

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
# 프롬프트 템플릿 정의
prompt = ChatPromptTemplate.from_template("주제 {topic}에 대해 짧은 설명을 해주세요.")

# %%
model = ChatOpenAI( 
    model="lmstudio-community/gemma-2-2b-it-GGUF",
    base_url="http://host.docker.internal:12345/v1",
    api_key="lm-studio",
    temperature=0.7
)

# %%
output_parser = StrOutputParser() # 출력 파서를 문자열로 설정

# %%
# 파이프라인 설정 : 주제를 받아 프롬프트 생성 -> 모델 응답 -> 문자열 파싱
chain = (
    {"topic": RunnablePassthrough()}
    | prompt
    | model
    | output_parser
)

# %%
chain.invoke("RAG에 대해 알려줘")
# Out:
# 'RAG(**Real-time Active Generation**)은 **실시간으로 활동적인 콘텐츠를 생성하는 AI 기술**입니다. 즉, 사용자의 입력에 따라 실시간으로 이미지, 글, 음악 등 다양한 형식의 콘텐츠를 만들어내는 능력을 말합니다.  \n\n**RAG은 다음과 같은 특징을 가지고 있습니다.**\n\n* **실시간 생성:** 사용자가 요청하는 정보를 기반으로 실시간에 콘텐츠를 생성합니다.\n* **다양한 분야 적용 가능:** 이미지, 글쓰기, 음악, 코드 등 다양한 분야에서 활용될 수 있습니다. \n* **사용자 인터페이스 간편:**  쉽게 사용할 수 있도록 사용자 친화적인 인터페이스를 제공합니다.\n\n**RAG의 장점:**\n\n* **창의성**: 사용자의 개인적인 요구에 맞는 새로운 콘텐츠를 생성할 수 있습니다.\n* **효율성**: 시간과 노력을 절약하는 데 도움이 됩니다.\n* **혁신**:  새로운 분야 발굴 및 창업 기회를 제공합니다.\n\n**RAG의 미래 전망:** \n\nRAG 기술은 빠르게 발전하고 있으며,  AI 모델의 성능 향상과 더불어 다양한 분야에서 활용 가능성이 높습니다. 예를 들어,  \n* **콘텐츠 제작**: 영화, 게임 등 콘텐츠 제작에 사용될 수 있습니다. \n* **교육**:  학습 자료 및 교육 콘텐츠를 생성할 수 있습니다.\n* **디지털 마켓**:  소비자들에게 맞춤형 상품이나 서비스 제공 가능합니다.\n\n\n'
